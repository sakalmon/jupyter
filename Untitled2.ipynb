# %%
import pandas as pd

# %%
df = pd.read_csv("Result Files\Bosch-R07 Firmware_CEQ0216.csv", header=2)

# %%
df
# Out:
#           Team Lead        Operator                              Start  \
# 0    David Halafoou  David Halafoou  2021-08-20T09:11:00.6196436+10:00
# 1    David Halafoou  David Halafoou  2021-08-20T09:11:02.4517844+10:00
# 2    David Halafoou  David Halafoou  2021-08-20T09:11:02.5235518+10:00
# 3    David Halafoou  David Halafoou  2021-08-20T09:11:07.4753323+10:00
# 4    David Halafoou  David Halafoou  2021-08-20T09:11:05.5374869+10:00
# ..              ...             ...                                ...
# 468      Sakal Mon       Sakal Mon   2021-08-20T11:50:07.1643939+10:00
# 469      Sakal Mon       Sakal Mon   2021-08-20T11:50:06.9160582+10:00
# 470      Sakal Mon       Sakal Mon   2021-08-20T11:50:12.5400558+10:00
# 471      Sakal Mon       Sakal Mon   2021-08-20T11:50:13.5273713+10:00
# 472      Sakal Mon       Sakal Mon   2021-08-20T11:50:20.4249188+10:00
#
#                                 Finish     Serial       Host  Index  Passed  \
# ...

# %%
t1 = df['T1Freq']

# %%
t2 = df['T2Freq']

# %%
fig = df.plot.scatter('T1Freq', 'T2Freq')

# %%
dir(fig)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_text',
#  '_adjustable',
#  '_agg_filter',
#  '_alias_map',
#  '_alpha',
#  '_anchor',
#  '_animated',
#  '_aspect',
#  '_autoscaleXon',
#  '_autoscaleYon',
#  '_autotitlepos',
#  '_axes',
#  '_axes_class',
#  '_axes_locator',
#  '_axisbelow',
#  '_box_aspect',
#  '_callbacks',
#  '_check_no_units',
#  '_clipon',
#  '_clippath',
#  '_colorbars',
#  '_contains',
#  '_convert_dx',
#  '_current_image',
#  '_default_contains',
#  '_facecolor',
#  '_fill_between_x_or_y',
#  '_frameon',
#  '_gci',
#  '_gen_axes_patch',
# ...
