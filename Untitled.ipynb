# %%
import pandas as pd

# %%
df = pd.read_csv('Downloaded/Ramen_Ratings/ramen-ratings.csv')

# %%
pd.set_option('display.max_rows', 100)

# %%
df['Stars'] = df['Stars'].replace('Unrated', 0)

# %%
df['Stars'] = df['Stars'].astype(float)

# %%
filt = df['Stars'] == 5.0

# %%
df = df.loc[filt]

# %%
df = df.sort_values(by='Stars', ascending=False)

# %%
df.groupby('Country').apply(display)
# Out:
#      Review #  Brand                                            Variety Style  \
# 512      2068  Maggi  Fusian Special Edition Ow... Ow... Spicy Cow M...  Pack
#
#        Country  Stars Top Ten
# 512  Australia    5.0     NaN
#      Review #   Brand                                 Variety Style Country  \
# 540      2040  Nissin  Cup Noodles Sabor Franhp Com Requeijao   Cup  Brazil
#
#      Stars Top Ten
# 540    5.0     NaN
#      Review # Brand                                        Variety Style  \
# 721      1859  Mama    Instant Noodles chicken Green Curry Flavour  Pack
# 849      1731  Mama  Instant Noodles Creamy Shrimp Tom Yum Flavour  Pack
#
#       Country  Stars Top Ten
# 721  Cambodia    5.0     NaN
# 849  Cambodia    5.0     NaN
#       Review #            Brand                                    Variety  \
# 1031      1549  Sapporo Ichiban  Chow Mein Japanese Style Noodles Yakisoba
# 1239      1341    Plats Du Chef        Cuisine Adventures Chicken Pho Soup
#
# ...
