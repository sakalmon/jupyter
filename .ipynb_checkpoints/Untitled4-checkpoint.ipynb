# %%
import pandas as pd
import os

# %%
file_path = os.path.join('Result Files', '6171-R&D-00000078_CEQ0134.csv')

# %%
pd.read_csv(file_path, header=2)
# Out:
#      Team Lead Operator                              Start  \
# 0    Sakal Mon    KMANE  2021-08-06T11:22:09.3400625+10:00
# 1    Sakal Mon    KMANE  2021-08-06T11:22:11.5439416+10:00
# 2    Sakal Mon    KMANE  2021-08-06T11:22:13.3252433+10:00
# 3    Sakal Mon    KMANE  2021-08-06T11:22:15.9668297+10:00
# 4    Sakal Mon    KMANE  2021-08-06T11:22:27.4989389+10:00
# ..         ...      ...                                ...
# 335  Sakal Mon    KMANE  2021-08-06T11:59:09.3644385+10:00
# 336  Sakal Mon    KMANE  2021-08-06T11:59:12.5660286+10:00
# 337  Sakal Mon    KMANE  2021-08-06T11:59:15.4873893+10:00
# 338  Sakal Mon    KMANE  2021-08-06T11:59:19.1123073+10:00
# 339  Sakal Mon    KMANE  2021-08-06T11:59:58.2332455+10:00
#
#                                 Finish      Serial  Host Serial  Index  \
# 0    2021-08-06T11:22:24.1390066+10:00   168197229    682630989      1
# 1    2021-08-06T11:22:25.9527191+10:00    67453435    682051906      2
# ...
